# %% [markdown]
# This Notebook was used to get me used to Newtonian solvers and ODE integrators in general. It solves some basic Physics problems: damped SHO, orbital motion,...
#
# Created during an Undergraduate Research Experience Programme placement at Imperial College London 2020
# by Jakub Dranczewski.
#
# To contact me, try (in no particular order)
# * jbd17@ic.ac.uk (unless I left)
# * jakub.dranczewski@gmail.com
# * jdranczewski.github.io (there should be an email in the CV)
# * some other social media platform
#
# This code should also be available at https://github.com/jdranczewski/optical-levitation-raytracing-experiments

# %%
from sys import path
path.insert(0,'..')

import numpy as np
from scipy.integrate import odeint, solve_ivp
# %matplotlib notebook
import matplotlib.pyplot as plt
import cProfile

# %%
init_state = np.zeros(4)

# %%
def euler(func, init, t, args):
    r = np.zeros((len(t), len(init)))
    r[0] = init
    for i in range(1, len(t)):
        r[i] = r[i-1] + (t[i]-t[i-1]) * func(t[i-1], r[i-1], *args)
    return r

# %%
def derivatives(t, state, forces, mass):
    if len(forces):
        acc = np.sum([force(state, t) for force in forces], axis=0)/mass
    else:
        acc = [0,0]
#     print(state)
    return np.array([state[2], state[3], acc[0], acc[1]])

# %%
def const_force_factory(force):
    def constant_force(state, t):
        return force
    return constant_force

# %%
def drag_factory(coeff):
    def drag(state, t):
        return -coeff*state[2:]
    return drag

# %%
def central_factory(coeff):
    def central(state, t):
        return -coeff*state[:2]
    return central

# %%
def linear_force_factory(coeff):
    def central(state, t):
        return -coeff*state[:2]/np.sqrt((state[0]**2 + state[1]**2))
    return central

# %%
derivatives(0, init_state, [const_force_factory([1,.5]), const_force_factory([2,-3])], 2)
# Out:
# array([ 0.  ,  0.  ,  1.5 , -1.25])

# %% [markdown]
# # Basic tests

# %%
forces = [const_force_factory([0,-9.81])]
res = odeint(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1), tfirst=True)
res2 = euler(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1))

# %%
fig, ax = plt.subplots(1,4, sharex=True, sharey=True)
ax = ax.flatten()
n = [5,10,25,100]
for i, axis in enumerate(ax):
    res = odeint(derivatives, [0,0,1,5], np.linspace(0,1,n[i]), args=(forces, 1), tfirst=True)
    res2 = euler(derivatives, [0,0,1,5], np.linspace(0,1,n[i]), args=(forces, 1))
    res3 = solve_ivp(derivatives, (0,1), [0,0,1,5], args=(forces, 1), t_eval=np.linspace(0,1,n[i]))
    tspace = np.linspace(0,1,100)
    axis.plot(1*tspace, 5*tspace-9.81*tspace**2/2, "--", label="exact")
    axis.plot(res[:,0], res[:,1], label="odeint")
    axis.plot(res2[:,0], res2[:,1], label="Euler")
    axis.plot(res3.y.T[:,0], res3.y.T[:,1], label="solve_ivp")
#     axis.axis("equal")
ax[-1].legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print("odeint:    ", end="")
# %timeit res = odeint(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1), tfirst=True)
print("euler:     ", end="")
# %timeit res2 = euler(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1))
print("solve_ivp: ", end="")
# %timeit res3 = solve_ivp(derivatives, (0,1), [0,0,1,5], args=(forces, 1), t_eval=np.linspace(0,1,100))
# Out:
# odeint:    279 µs ± 4.37 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# euler:     2.02 ms ± 120 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# solve_ivp: 1.62 ms ± 5.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
print("odeint:    ", end="")
# %timeit res = odeint(derivatives, [0,0,1,5], np.linspace(0,1,5), args=(forces, 1), tfirst=True)
print("euler:     ", end="")
# %timeit res2 = euler(derivatives, [0,0,1,5], np.linspace(0,1,5), args=(forces, 1))
print("solve_ivp: ", end="")
# %timeit res3 = solve_ivp(derivatives, (0,1), [0,0,1,5], args=(forces, 1), t_eval=np.linspace(0,1,5))
# Out:
# odeint:    245 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# euler:     118 µs ± 3.24 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# solve_ivp: 1.52 ms ± 3.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def test(init, times, forces):
    fig, ax = plt.subplots(1,4, sharex=True, sharey=True)
    ax = ax.flatten()
    n = [5,10,25,100]
    for i, axis in enumerate(ax):
        res = odeint(derivatives, init, times[i], args=(forces, 1), tfirst=True)
        res2 = euler(derivatives, init, times[i], args=(forces, 1))
        res3 = solve_ivp(derivatives, (times[i][0], times[i][-1]), init, args=(forces, 1), t_eval=times[i])
        axis.plot(res[:,0], res[:,1], "x--", label="odeint")
        axis.plot(res2[:,0], res2[:,1], "x--", label="Euler")
        axis.plot(res3.y.T[:,0], res3.y.T[:,1], "x--", label="solve_ivp")
    ax[-1].legend()
    return (ax, res, res2, res3)

# %%
ax, res, res2, res3 = test([1,2,1.2,1.5], [np.linspace(0,1,n) for n in (5,10,25,100)], [const_force_factory([0,-9.81])])
tspace = np.linspace(0,1,100)
for axis in ax:
    axis.plot(1+1.2*tspace, 2+1.5*tspace-9.81*tspace**2/2, "-", label="exact")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Linear acceleration

# %%
ax, res, res2, res3 = test([1,2,1.2,1.5], [np.linspace(0,1,n) for n in (5,10, 10, 10)], [const_force_factory([1.5,2.3])])
tspace = np.linspace(0,1,100)
for axis in ax:
    axis.plot(1+1.2*tspace+1.5*tspace**2/2, 2+1.5*tspace+2.3*tspace**2/2, "-", label="exact")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots(1,3, sharex=True, sharey=True)
ax = ax.flatten()
ax[0].plot(res[:,2], "x--")
ax[1].plot(res2[:,2], "x--")
ax[2].plot(res3.y.T[:,2], "x--")
ax[0].plot(res[:,3], "x--")
ax[1].plot(res2[:,3], "x--")
ax[2].plot(res3.y.T[:,3], "x--")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # An orbit

# %%
ax, res, res2, res3 = test([1,0,0,1], [np.linspace(0,5,n) for n in (5,11, 25, 101)], [central_factory(2)])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # force balance

# %%
# Small drift when the forces don't add up absolutely perfectly
forces = [const_force_factory([1,0]), const_force_factory([np.cos(np.pi*2/3), np.sin(np.pi*2/3)]), const_force_factory([np.cos(np.pi*2/3), -np.sin(np.pi*2/3)])]
ax, res, res2, res3 = test([1,2,0,0], [np.linspace(0,10,n) for n in (5,10,25,1000)], forces)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Drag

# %%
# Small drift when the forces don't add up absolutely perfectly
forces = [drag_factory(1), const_force_factory((0., -9.81))]
ax, res, res2, res3 = test([0,0,1.5,10], [np.linspace(0,2,n) for n in (5,10,25,10000)], forces)
tspace = np.linspace(0,2,100)
for axis in ax:
    axis.plot(1.5*(1-np.exp(-tspace)), (10+9.81)*(1-np.exp(-tspace))-9.81*tspace, "-", label="exact")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Simple Harmonic Oscillator

# %% [markdown]
# ## Normal

# %%
init = np.array([1,0,0,0.3])
times = [np.linspace(0,10,n) for n in (20,25,100,2000)]
c = 0.7
forces = [central_factory(1), drag_factory(c)]

fig, ax = plt.subplots(2,4, sharex=True, sharey="row")
for i in range(4):
    res = odeint(derivatives, init, times[i], args=(forces, 1), tfirst=True)
    res2 = euler(derivatives, init, times[i], args=(forces, 1))
    res3 = solve_ivp(derivatives, (times[i][0], times[i][-1]), init, args=(forces, 1), t_eval=times[i])
    ax[0][i].plot(times[i], res[:,0], "x--", label="odeint")
    ax[1][i].plot(times[i], res[:,1], "x--", label="odeint")
    ax[0][i].plot(times[i], res2[:,0], "x--", label="Euler")
    ax[1][i].plot(times[i], res2[:,1], "x--", label="Euler")
    ax[0][i].plot(times[i], res3.y.T[:,0], "x--", label="solve_ivp")
    ax[1][i].plot(times[i], res3.y.T[:,1], "x--", label="solve_ivp")
    ax[0,i].plot(times[i], np.exp(-c/2*times[i]) * (np.cos(np.sqrt(1-c**2/4)*times[i]) + c/2/np.sqrt(1-c**2/4)*np.sin(np.sqrt(1-c**2/4)*times[i])))
ax[0,-1].legend()
ax[0,0].set_ylim(-1.3,1.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.3, 1.3)

# %%
ax, res, res2, res3 = test(init, times, forces)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # How many function calls?

# %%
forces = [const_force_factory([0,-9.81])]

# %%
cProfile.run("odeint(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1), tfirst=True)")
# Out:
#          238 function calls (235 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#        12    0.000    0.000    0.000    0.000 <ipython-input-4-051b5c2045fa>:1(derivatives)
#        12    0.000    0.000    0.000    0.000 <ipython-input-4-051b5c2045fa>:3(<listcomp>)
#        12    0.000    0.000    0.000    0.000 <ipython-input-5-ca935724f712>:2(constant_force)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#         1    0.000    0.000    0.000    0.000 _methods.py:56(_all)
#         2    0.000    0.000    0.000    0.000 copy.py:66(copy)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:2100(_sum_dispatcher)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:2105(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2249(any)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#        13    0.000    0.000    0.000    0.000 fromnumeric.py:70(_wrapreduction)
#        13    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:1148(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:1152(diff)
#         1    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:23(linspace)
#         1    0.000    0.000    0.000    0.000 multiarray.py:634(result_type)
#         1    0.000    0.000    0.000    0.000 numeric.py:1816(isscalar)
#         1    0.000    0.000    0.001    0.001 odepack.py:28(odeint)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        15    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#     17/14    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.001    0.001 {built-in method scipy.integrate._odepack.odeint}
#         1    0.000    0.000    0.000    0.000 {method '__copy__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}

# %%
cProfile.run("euler(derivatives, [0,0,1,5], np.linspace(0,1,100), args=(forces, 1))")
# Out:
#          1525 function calls (1522 primitive calls) in 0.005 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#        99    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(sum)
#        99    0.000    0.000    0.000    0.000 <ipython-input-103-ca935724f712>:2(constant_force)
#         1    0.001    0.001    0.004    0.004 <ipython-input-107-c1a6a8cc3c32>:1(euler)
#        99    0.001    0.000    0.003    0.000 <ipython-input-150-051b5c2045fa>:1(derivatives)
#        99    0.000    0.000    0.000    0.000 <ipython-input-150-051b5c2045fa>:3(<listcomp>)
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#        99    0.000    0.000    0.000    0.000 fromnumeric.py:2100(_sum_dispatcher)
#        99    0.000    0.000    0.002    0.000 fromnumeric.py:2105(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2249(any)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#       100    0.000    0.000    0.002    0.000 fromnumeric.py:70(_wrapreduction)
#       100    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:23(linspace)
#         1    0.000    0.000    0.000    0.000 multiarray.py:634(result_type)
#         1    0.000    0.000    0.000    0.000 numeric.py:1816(isscalar)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.exec}
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       102    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       101    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#   103/100    0.000    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       100    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       100    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}

# %%
cProfile.run("solve_ivp(derivatives, (0,1), [0,0,1,5], args=(forces, 1), t_eval=np.linspace(0,1,100))")
# Out:
#          1237 function calls (1222 primitive calls) in 0.005 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumprod)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#        47    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(hstack)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(norm)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(searchsorted)
#        32    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(sum)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#        32    0.000    0.000    0.000    0.000 <ipython-input-103-ca935724f712>:2(constant_force)
#        32    0.000    0.000    0.001    0.000 <ipython-input-150-051b5c2045fa>:1(derivatives)
#        32    0.000    0.000    0.000    0.000 <ipython-input-150-051b5c2045fa>:3(<listcomp>)
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#        47    0.000    0.000    0.000    0.000 _asarray.py:14(asarray)
#        11    0.000    0.000    0.000    0.000 _asarray.py:86(asanyarray)
#         2    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#         1    0.000    0.000    0.000    0.000 base.py:115(__init__)
#        32    0.000    0.000    0.002    0.000 base.py:136(fun)
#         5    0.000    0.000    0.003    0.001 base.py:159(step)
#        32    0.000    0.000    0.002    0.000 base.py:19(fun_wrapped)
#         4    0.000    0.000    0.001    0.000 base.py:192(dense_output)
#         4    0.000    0.000    0.000    0.000 base.py:229(__init__)
#         4    0.000    0.000    0.000    0.000 base.py:235(__call__)
#         1    0.000    0.000    0.000    0.000 base.py:4(check_arguments)
#         1    0.000    0.000    0.000    0.000 common.py:19(validate_max_step)
#         1    0.000    0.000    0.000    0.000 common.py:26(warn_extraneous)
#         1    0.000    0.000    0.000    0.000 common.py:43(validate_tol)
#         8    0.000    0.000    0.000    0.000 common.py:59(norm)
#         1    0.000    0.000    0.000    0.000 common.py:64(select_initial_step)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:1272(_searchsorted_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:1276(searchsorted)
#        32    0.000    0.000    0.000    0.000 fromnumeric.py:2100(_sum_dispatcher)
#        32    0.000    0.000    0.001    0.000 fromnumeric.py:2105(sum)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_any_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2249(any)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3003(_cumprod_dispatcher)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3007(cumprod)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:52(_wrapfunc)
#        37    0.000    0.000    0.001    0.000 fromnumeric.py:70(_wrapreduction)
#        37    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:1148(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:1152(diff)
#         1    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:23(linspace)
#         1    0.000    0.000    0.005    0.005 ivp.py:156(solve_ivp)
#         1    0.000    0.000    0.000    0.000 ivp.py:28(prepare_events)
#        32    0.000    0.000    0.002    0.000 ivp.py:514(<lambda>)
#         8    0.000    0.000    0.000    0.000 linalg.py:112(isComplexType)
#         8    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#         8    0.000    0.000    0.000    0.000 linalg.py:2363(norm)
#         2    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:634(result_type)
#        47    0.000    0.000    0.000    0.000 multiarray.py:706(dot)
#         1    0.000    0.000    0.000    0.000 numeric.py:1816(isscalar)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:286(issubclass_)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:360(issubdtype)
#         5    0.000    0.000    0.000    0.000 rk.py:105(_estimate_error)
#         5    0.000    0.000    0.000    0.000 rk.py:108(_estimate_error_norm)
#         5    0.000    0.000    0.003    0.001 rk.py:111(_step_impl)
#         5    0.001    0.000    0.002    0.000 rk.py:14(rk_step)
#         4    0.000    0.000    0.001    0.000 rk.py:178(_dense_output_impl)
#         4    0.000    0.000    0.000    0.000 rk.py:527(__init__)
#         4    0.000    0.000    0.000    0.000 rk.py:534(_call_impl)
#         1    0.000    0.000    0.000    0.000 rk.py:85(__init__)
#         4    0.000    0.000    0.000    0.000 shape_base.py:1167(_tile_dispatcher)
#         4    0.000    0.000    0.000    0.000 shape_base.py:1171(tile)
#         8    0.000    0.000    0.000    0.000 shape_base.py:1243(<genexpr>)
#        12    0.000    0.000    0.000    0.000 shape_base.py:1253(<genexpr>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:24(atleast_1d)
#         2    0.000    0.000    0.000    0.000 shape_base.py:286(hstack)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.exec}
#        43    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        94    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#   115/100    0.001    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#        17    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'cumprod' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        37    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        37    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
