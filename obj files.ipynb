# %%
import ptracer as pt
import numpy as np
from importlib import reload
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
reload(pt)
# Out:
# <module 'ptracer' from '/home/jdranczewski/Documents/Imperial/UROP20/optical-levitation-raytracing-experiments/ptracer.py'>

# %%
with open("cruel_sphere.obj") as f:
    lines = f.readlines()

# %%
verts = np.array([np.array(l[2:-1].split(" ")).astype(float) for l in lines if l[:2]=='v '])*.25
print(verts)
# Out:
# [[-0.18090175  0.111805    0.13143125]
#  [ 0.069097    0.111805    0.21266225]
#  [ 0.18090175 -0.111805   -0.13143125]
#  [-0.069097   -0.111805   -0.21266225]
#  [-0.2236065  -0.111804    0.        ]
#  [-0.069097   -0.111805    0.21266225]
#  [ 0.18090175 -0.111805    0.13143125]
#  [ 0.         -0.25        0.        ]
#  [-0.18090175  0.111805   -0.13143125]
#  [ 0.069097    0.111805   -0.21266225]
#  [ 0.2236065   0.111804    0.        ]
#  [ 0.          0.25        0.        ]
#  [ 0.06571725 -0.1314345   0.202253  ]
#  [ 0.1469465   0.          0.20225425]
#  [-0.2377645   0.         -0.07725325]
#  [-0.040614   -0.2126635   0.12499875]
#  [ 0.06571725 -0.1314345  -0.202253  ]
#  [ 0.10633075 -0.2126635  -0.07725275]
#  [-0.17204725 -0.131434   -0.12499925]
#  [-0.1469465   0.         -0.20225425]
#  [-0.1314325  -0.212663    0.        ]
#  [ 0.212662   -0.131434    0.        ]
#  [-0.1469465   0.          0.20225425]
#  [ 0.          0.          0.25      ]
#  [-0.040614   -0.2126635  -0.12499875]
#  [-0.17204725 -0.131434    0.12499925]
#  [ 0.10633075 -0.2126635   0.07725275]
#  [ 0.2377645   0.         -0.07725325]
#  [-0.2377645   0.          0.07725325]
#  [ 0.2377645   0.          0.07725325]
#  [ 0.1469465   0.         -0.20225425]
#  [ 0.          0.         -0.25      ]
#  [ 0.17204725  0.131434    0.12499925]
#  [-0.06571725  0.1314345   0.202253  ]
#  [-0.212662    0.131434    0.        ]
#  [-0.06571725  0.1314345  -0.202253  ]
#  [ 0.17204725  0.131434   -0.12499925]
#  [ 0.040614    0.2126635   0.12499875]
#  [ 0.1314325   0.212663    0.        ]
#  [-0.10633075  0.2126635   0.07725275]
#  [-0.10633075  0.2126635  -0.07725275]
#  [ 0.040614    0.2126635  -0.12499875]]

# %%
faces = np.array([[int(v.split("/")[0])-1 for v in l[2:-1].split(" ")] for l in lines if l[:2]=='f '])
print(len(faces))
# Out:
# 960

# %%
verts[faces[0]]
# Out:
# array([[-0.25,  0.25, -0.25],
#        [ 0.25,  0.25,  0.25],
#        [ 0.25,  0.25, -0.25]])

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

for f in faces:
    t = pt.Triangle([0,0,0], *verts[f])
    t.plot(ax)

ax.plot(*verts.T, "x", c="tab:orange")
    
ax.set_xlim(-1.2,1.2)
ax.set_ylim(-1.2,1.2)
ax.set_zlim(-1.2,1.2)
# Out:
# <img src="data:image/png;base64,..." width="600">
# (-1.2, 1.2)

# %%
verts[faces[:,0]]
# Out:
# array([[-0.25,  0.25, -0.25],
#        [ 0.25,  0.25,  0.25],
#        [-0.25,  0.25,  0.25],
#        [ 0.25, -0.25, -0.25],
#        [ 0.25,  0.25, -0.25],
#        [-0.25,  0.25, -0.25],
#        [-0.25,  0.25, -0.25],
#        [ 0.25,  0.25,  0.25],
#        [-0.25,  0.25,  0.25],
#        [ 0.25, -0.25, -0.25],
#        [ 0.25,  0.25, -0.25],
#        [-0.25,  0.25, -0.25]])
